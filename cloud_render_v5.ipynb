# %% [markdown]
# **Run First Cell to get GPU info**

# %%
# 1st cell
# !nvidia-smi

# %% [markdown]
# ========================================================================================

# %% [markdown]
# **Run Second Cell to continue with the render process**

# %%
#Run 2nd cell to render 

print("Blender Cloud Rendering")
print("﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉﹉")
print()

#using google drive
from google.colab import drive
drive.mount("/gdrive")
import os

print()
print("______________________________________________________________________")
print()

#Blender installing options

print("Blender installation type :-")         
print("+---------+---------------------------------------------------------+")
print("|Item No. | Process                                                 |")
print("+---------+---------------------------------------------------------+")
print("|  1      | Download Blender from Official Blender Links            |")
print("|  2      | Install Blender from your Google Drive                  |")
print("|  3      | Skip to Render Settings (Blender already installed)     |")
print("+---------+---------------------------------------------------------+")

get = int(input("Enter Item number :- "))
print("______________________________________________________________________")

if get == 2:
  insblend_2_82 = "blender-2.82-linux64.tar.xz"  
  insblend_2_83_18 = "blender-2.83.18-linux-x64.tar.xz" 
  insblend_2_90_1 = "blender-2.90.1-linux64.tar.xz"  
  insblend_2_91_2 = "blender-2.91.2-linux64.tar.xz"
  insblend_2_92_0 = "blender-2.92.0-linux64.tar.xz" 
  insblend_2_93_7 = "blender-2.93.7-linux-x64.tar.xz" 
  insblend_3_0_0 = "blender-3.0.0-linux-x64.tar.xz" 
  insblend_3_1_2 = "blender-3.1.2-linux-x64.tar.xz"  
  insblend_3_2_2 = "blender-3.2.2-linux-x64.tar.xz"
  insblend_3_3_3 = "blender-3.3.3-linux-x64.tar.xz"
  insblend_3_4_1 = "blender-3.4.1-linux-x64.tar.xz"
  insblend_3_5_1 = "blender-3.5.1-linux-x64.tar.xz"

  inslist = [[1, insblend_2_82],
             [2, insblend_2_83_18],
             [3, insblend_2_90_1],
             [4, insblend_2_91_2],
             [5, insblend_2_92_0],
             [6, insblend_2_93_7],
             [7, insblend_3_0_0],
             [8, insblend_3_1_2],
             [9, insblend_3_2_2],
             [10, insblend_3_3_3],
             [11, insblend_3_4_1]]
             [11, insblend_3_5_1]]
  print()
  print()
  print()
  print("Links to download available Blender versions for installation :- ")
  print()
  print("+---------------+---------------------------------------------------------------------------------------------+")
  print("|Versions       | Blender Version links                                                                       |")
  print("+---------------+---------------------------------------------------------------------------------------------+")
  print("| 2.82          |  https://download.blender.org/release/Blender2.82/blender-2.82-linux64.tar.xz               |") 
  print("| 2.83          |  https://download.blender.org/release/Blender2.83/blender-2.83.18-linux-x64.tar.xz          |") 
  print("| 2.90          |  https://download.blender.org/release/Blender2.90/blender-2.90.1-linux64.tar.xz             |")  
  print("| 2.91          |  https://download.blender.org/release/Blender2.91/blender-2.91.2-linux64.tar.xz             |")
  print("| 2.92          |  https://download.blender.org/release/Blender2.92/blender-2.92.0-linux64.tar.xz             |")
  print("| 2.93          |  https://download.blender.org/release/Blender2.93/blender-2.93.7-linux-x64.tar.xz           |")
  print("| 3.0           |  https://download.blender.org/release/Blender3.0/blender-3.0.0-linux-x64.tar.xz             |")
  print("| 3.1           |  https://download.blender.org/release/Blender3.1/blender-3.1.2-linux-x64.tar.xz             |")
  print("| 3.2           |  https://download.blender.org/release/Blender3.2/blender-3.2.2-linux-x64.tar.xz             |")
  print("| 3.3           |  https://download.blender.org/release/Blender3.3/blender-3.3.3-linux-x64.tar.xz             |")
  print("| 3.4           |  https://download.blender.org/release/Blender3.4/blender-3.4.1-linux-x64.tar.xz             |")
  print("| 3.5           |  https://download.blender.org/release/Blender3.5/blender-3.5.1-linux-x64.tar.xz             |")
  print("+---------------+---------------------------------------------------------------------------------------------+")
  print("               Mid-mouse click on the links to open it in a new tab and download")
  print()
  print()
  print("Select Blender .tar.xz file name added on your Google Drive :-")         
  print("+---------+----------------------------------------------------------+")
  print("|Item No. | Availabe Blender Versions                                |")
  print("+---------+----------------------------------------------------------+")

  for l in inslist:
    print("|", l[0], " "*(6 - len(str(l[0]))),"|", l[1], " "*(55 - len(str(l[1]))),"|")

  print("+---------+----------------------------------------------------------+")
  print()
  print()

  insversion = int(input("Enter Item number :- "))
  if insversion == 1:
    finstall = insblend_2_82
  elif insversion == 2:
    finstall = insblend_2_83_18   
  elif insversion == 3:
    finstall = insblend_2_90_1 
  elif insversion == 4:
    finstall = insblend_2_91_2
  elif insversion == 5:
    finstall = insblend_2_92_0 
  elif insversion == 6:
    finstall = insblend_2_93_7 
  elif insversion == 7:
    finstall = insblend_3_0_0  
  elif insversion == 8:
    finstall = insblend_3_1_2  
  elif insversion == 9:
    finstall = insblend_3_2_2
  elif insversion == 10:
    finstall = insblend_3_3_3
  elif insversion == 11:
    finstall = insblend_3_4_1    
  elif insversion == 12:
    finstall = insblend_3_5_1    
  else:
    print("No such Item is available")  


  print()
  dirblend = ("/gdrive/MyDrive/Blender_GC/"+ finstall)
  print("Blender Application directory is set to",dirblend)
  # !tar xf $dirblend

  fdot = 0
  for k in range (len(finstall) - 1,0,-1):
    if finstall[k] == ".":
      fdot += 1
      if fdot == 2:
        vari = k
        break
  term = finstall[:vari]
  print(term)



elif get == 1:
  blend_2_82 = "https://download.blender.org/release/Blender2.82/blender-2.82-linux64.tar.xz" 
  blend_2_83_18 = "https://download.blender.org/release/Blender2.83/blender-2.83.18-linux-x64.tar.xz" 
  blend_2_90_1 = "https://download.blender.org/release/Blender2.90/blender-2.90.1-linux64.tar.xz"  
  blend_2_91_2 = "https://download.blender.org/release/Blender2.91/blender-2.91.2-linux64.tar.xz"
  blend_2_92_0 = "https://download.blender.org/release/Blender2.92/blender-2.92.0-linux64.tar.xz" 
  blend_2_93_7 = "https://download.blender.org/release/Blender2.93/blender-2.93.7-linux-x64.tar.xz"  
  blend_3_0_0 = "https://download.blender.org/release/Blender3.0/blender-3.0.0-linux-x64.tar.xz"     
  blend_3_1_2 = "https://download.blender.org/release/Blender3.1/blender-3.1.2-linux-x64.tar.xz" 
  blend_3_2_2 = "https://download.blender.org/release/Blender3.2/blender-3.2.2-linux-x64.tar.xz" 
  blend_3_3_3 = "https://download.blender.org/release/Blender3.3/blender-3.3.3-linux-x64.tar.xz" 
  blend_3_4_1 = "https://download.blender.org/release/Blender3.4/blender-3.4.1-linux-x64.tar.xz" 
  blend_3_5_1 = "https://download.blender.org/release/Blender3.5/blender-3.5.1-linux-x64.tar.xz" 

  nlist = [[1, "Blender_2.82"],
           [2, "Blender_2.83"],
           [3, "Blender_2.90"],
           [4, "Blender_2.91"],
           [5, "Blender_2.92"],
           [6, "Blender_2.93"],
           [7, "Blender_3.0 "],
           [8, "Blender_3.1"],
           [9, "Blender_3.2"],
           [10, "Blender_3.3"],
           [11, "Blender_3.4"],]
           [12, "Blender_3.5"],]
  print()
  print("Available Blender versions list :-")         
  print("+---------+--------------------------------+")
  print("|Item No. | Blender Versions               |")
  print("+---------+--------------------------------+")

  for i in nlist:
    print("|", i[0], " "*(6 - len(str(i[0]))),"|", i[1], " "*(29 - len(str(i[1]))),"|")

  print("+---------+--------------------------------+")
  print()

  version = int(input("Enter Item number :- "))
  if version == 1:
    download = blend_2_82
  elif version == 2:
    download = blend_2_83_18   
  elif version == 3:
    download = blend_2_90_1 
  elif version == 4:
    download = blend_2_91_2
  elif version == 5:
    download = blend_2_92_0
  elif version == 6:
    download = blend_2_93_7   
  elif version == 7:
    download = blend_3_0_0  
  elif version == 8:
    download = blend_3_1_2
  elif version == 9:
    download = blend_3_2_2
  elif version == 10:
    download = blend_3_3_3
  elif version == 11:
    download = blend_3_4_1  
  elif version == 12:
    download = blend_3_5_1  
  else:
    print("No such Item is available")  




  print()

  # !wget $download
  print()
  print("______________________________________________________________________")
  print()
  fslash = 0
  for j in range (0,len(download)):
    if download[j] == "/":
      fslash += 1
      if fslash == 5:
        tempvar = j
        break
  exec = download[tempvar + 1:]
  print(exec)

  fdot = 0
  for k in range (len(exec) - 1,0,-1):
    if exec[k] == ".":
      fdot += 1
      if fdot == 2:
        vari = k
        break

  term = exec[:vari]
  # !tar xf $exec
  print("______________________________________________________________________")

elif get == 3:
  print("Skipping to Render Settings...")
  print()
  print("______________________________________________________________________")

else:
  print("Wrong Input")
  print()
  print("______________________________________________________________________")


print()
print()

#selecting the render file 
blend = str(input("Enter Blender File name :- "))
filename = "/gdrive/MyDrive/Blender_GC/" + blend
print("File location set to :- ",filename)

print()
print(term)
print("Executing Blender...")
print()

#input render info

print("______________________________________________________________________")
print()
print("Select Render Device '1' or '2' (Optix not compatible with Tesla K80 GPU):- ")
print()
print("+---------+------------------------+")
print("|Item No. | Render Devices         |")
print("+---------+------------------------+")
print("|  1      | Cycles CUDA            |")
print("|  2      | Cycles OptiX           |")
print("|  3      | EEVEE                  |")
print("+---------+------------------------+")
print()

device = str(input("Enter Item number :- "))
print("______________________________________________________________________")
print()
print("Enter Render type '1' or '2' :- ")
print()
print("+---------+---------------------------------+")
print("|Item No. | Frame type                      |")
print("+---------+---------------------------------+")
print("|  1      | Single Frame                    |")
print("|  2      | Animation (Multiple Frames)     |")
print("+---------+---------------------------------+")
print()

frame = int(input("Enter Item number :- "))
print("______________________________________________________________________")
print()

#cycles render device

if frame == 2:
  start = int(input("Enter starting frame no. :- "))
  end = int(input("Enter ending frame no. :- "))
  if device =="2" or device == "optix" or device == "OptiX" or device == "OPTIX" or device == "Optix": 
    # !sudo /content/$term/blender -b $filename -noaudio  -E 'CYCLES' -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -s $start -e $end -a -- --cycles-device OPTIX
  elif device == "1" or device == "cuda" or device == "CUDA" or device == "Cuda":
    # !/content/$term/blender -b $filename -noaudio  -E 'CYCLES' -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -s $start -e $end -a -- --cycles-device CUDA
  elif device == "3" or device == "eevee" or device == "EEVEE" or device == "Eevee":
    # !/content/$term/blender -b $filename -noaudio -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -s $start -e $end -a 
  else:
    print("Wrong input!")

elif frame == 1: 
  single = int(input("Enter frame number to be rendered :- "))
  if device =="2" or device == "optix" or device == "OptiX" or device == "OPTIX" or device == "Optix": 
    # !sudo /content/$term/blender -b $filename -noaudio  -E 'CYCLES' -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -f $single -- --cycles-device OPTIX
  elif device == "1" or device == "cuda" or device == "CUDA" or device == "Cuda":
    # !/content/$term/blender -b $filename -noaudio  -E 'CYCLES' -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -f $single -- --cycles-device CUDA
  elif device == "3" or device == "eevee" or device == "EEVEE" or device == "Eevee":
    # !/content/$term/blender -b $filename -noaudio -o '/gdrive/MyDrive/Blender_GC/'Output'/Frame_#####' -f $single 
  else:
    print("Wrong input!")
else:
  print("Wrong input!")

print()
print("======================================================================")
print()
